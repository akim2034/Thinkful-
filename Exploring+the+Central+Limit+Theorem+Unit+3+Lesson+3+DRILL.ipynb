# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10, 0.5, 10000)

plt.figure(figsize=(13, 6))

plt.subplot(1, 2, 1)
plt.hist(pop1, alpha=.7)
plt.axvline(pop1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(pop1.mean() + pop1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(pop1.mean()- pop1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Population 1 Distribution')

plt.subplot(1, 2, 2)
plt.hist(pop2, alpha=.7)
plt.axvline(pop2.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(pop2.mean() + pop2.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(pop2.mean()- pop2.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Population 2 Distribution')

plt.tight_layout()
plt.show()

# %%
sample1 = np.random.binomial(10, .2, 100)
sample2 = np.random.binomial(10, .5, 100)

plt.figure(figsize=(13, 6))

plt.subplot(1, 2, 1)
plt.hist(sample1, alpha=.7)
plt.axvline(sample1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample1.mean() + sample1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample1.mean()-sample1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 1 Distribution (n=100)')

plt.subplot(1, 2, 2)
plt.hist(sample2, alpha=.7)
plt.axvline(sample2.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample2.mean() + sample2.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample2.mean()-sample2.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 2 Distribution (n=100)')

plt.tight_layout()
plt.show()

# %%
sample1b = np.random.binomial(10, .2, 1000)
sample2b = np.random.binomial(10, .5, 1000)

plt.figure(figsize=(13, 6))

plt.subplot(1, 2, 1)
plt.hist(sample1b, alpha=.7)
plt.axvline(sample1b.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample1b.mean() + sample1b.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample1b.mean()-sample1b.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 1 Distribution (n=1000)')

plt.subplot(1, 2, 2)
plt.hist(sample2b, alpha=.7)
plt.axvline(sample2b.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample2b.mean() + sample2b.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample2b.mean()-sample2b.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 2 Distribution (n=1000)')

plt.tight_layout()
plt.show()

# %%
sample1c = np.random.binomial(10, .2, 20)
sample2c = np.random.binomial(10, .5, 20)

plt.figure(figsize=(13, 6))

plt.subplot(1, 2, 1)
plt.hist(sample1c, alpha=.7)
plt.axvline(sample1c.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample1c.mean() + sample1c.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample1c.mean()-sample1c.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 1 Distribution (n=20)')

plt.subplot(1, 2, 2)
plt.hist(sample2c, alpha=.7)
plt.axvline(sample2c.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(sample2c.mean() + sample2c.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(sample2c.mean()-sample2c.std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Sample 2 Distribution (n=20)')

plt.tight_layout()
plt.show()

# %%
print(np.mean(pop1))
print(np.mean(sample1))
print(np.mean(sample1b))
print(np.mean(sample1c))

print(np.mean(pop2))
print(np.mean(sample2))
print(np.mean(sample2b))
print(np.mean(sample2c))

print(np.std(pop1))
print(np.std(sample1))
print(np.std(sample1b))
print(np.std(sample1c))

print(np.std(pop2))
print(np.std(sample2))
print(np.std(sample2b))
print(np.std(sample2c))
# Out:
# 1.9894
# 1.83
# 2.087
# 1.5
# 4.9835
# 4.96
# 5.001
# 5.15
# 1.25884377109
# 1.25741798937
# 1.25436477948
# 1.07238052948
# 1.57105943554
# 1.61195533437
# 1.61027916834
# 1.35185058346

# %% [markdown]
# The mean stays relatively the same for samples until the size is decreased to 20. In that case, mean was further away from the population mean. For standard deviation was also changed significantly in size of 20 because of the outliers that skewed the distribution.

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Compute the difference between the two sample means.
diff=sample2.mean( ) -sample1.mean()
print(diff)
# Out:
# 1.72
# 4.84
# 1.22539789456
# 1.56665248221
# 3.12

# %%
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])

# The squared standard deviations are divided by the sample size and summed, then we take
# the square root of the sum. 
diff_se = (sum(sd ** 2 / size)) ** 0.5  

#The difference between the means divided by the standard error: T-value.  
print(diff/diff_se)
# Out:
# 15.6865144017

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=15.607884761686153, pvalue=1.0223488505627684e-35)
